# %%
def sumar(a,b):
    return a + b

# %%
sumar(3,7)
# Out:
# 10

# %%
from goodrich.ch06.array_stack import ArrayStack

# %%
AS = ArrayStack()

# %%
AS.push
# Out:
# <bound method ArrayStack.push of <goodrich.ch06.array_stack.ArrayStack object at 0x74dd00eb7aa0>>

# %%
Ejercicio 1.1
# Out:
#   Cell In[1], line 1
#     Ejercicio 1.1
#               ^
# SyntaxError: invalid syntax

# %%
Escribir una funcios sumar_pares(Q) que recibe un queue de números enteros y:
1.
